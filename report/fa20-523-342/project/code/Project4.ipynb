# %%
import pandas as pd
import matplotlib as mlp
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import os
import requests
import shutil
import numpy as np
import statsmodels.api as sm
import math
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from scipy import stats
from scipy.stats import kurtosis, skew
# %matplotlib inline

# %%
#Download the latest CSV file from the WHO website
url = 'https://covid19.who.int/WHO-COVID-19-global-data.csv'
r = requests.get(url, allow_redirects=True)
#Save the content with name.
open('WHO-COVID-19-global-data.csv', 'wb').write(r.content)
# Out:
# 3433564

# %%
dataframe = pd.read_csv('WHO-COVID-19-global-data.csv')
dataframe.head
# Out:
# <bound method NDFrame.head of       Date_reported Country_code      Country WHO_region  New_cases  \
# 0        2020-01-03           AF  Afghanistan       EMRO          0
# 1        2020-01-04           AF  Afghanistan       EMRO          0
# 2        2020-01-05           AF  Afghanistan       EMRO          0
# 3        2020-01-06           AF  Afghanistan       EMRO          0
# 4        2020-01-07           AF  Afghanistan       EMRO          0
# ...             ...          ...          ...        ...        ...
# 80488    2020-12-05           ZW     Zimbabwe       AFRO        123
# 80489    2020-12-06           ZW     Zimbabwe       AFRO         70
# 80490    2020-12-07           ZW     Zimbabwe       AFRO        101
# 80491    2020-12-08           ZW     Zimbabwe       AFRO        121
# 80492    2020-12-09           ZW     Zimbabwe       AFRO          0
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 0                     0           0                  0
# 1                     0           0                  0
# 2                     0           0                  0
# 3                     0           0                  0
# 4                     0           0                  0
# ...                 ...         ...                ...
# 80488             10547           1                281
# 80489             10617          10                291
# 80490             10718           0                291
# 80491             10839           3                294
# 80492             10839           0                294
#
# [80493 rows x 8 columns]>

# %%
USA=dataframe[dataframe.Country == 'United States of America']
USA
# Out:
#       Date_reported Country_code                   Country WHO_region  \
# 76723    2020-01-03           US  United States of America       AMRO
# 76724    2020-01-04           US  United States of America       AMRO
# 76725    2020-01-05           US  United States of America       AMRO
# 76726    2020-01-06           US  United States of America       AMRO
# 76727    2020-01-07           US  United States of America       AMRO
# ...             ...          ...                       ...        ...
# 77061    2020-12-06           US  United States of America       AMRO
# 77062    2020-12-07           US  United States of America       AMRO
# 77063    2020-12-08           US  United States of America       AMRO
# 77064    2020-12-09           US  United States of America       AMRO
# 77065    2020-12-10           US  United States of America       AMRO
#
#        New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 76723          0                 0           0                  0
# 76724          0                 0           0                  0
# 76725          0                 0           0                  0
# 76726          0                 0           0                  0
# 76727          0                 0           0                  0
# ...          ...               ...         ...                ...
# 77061     213127          14191298        2426             276503
# 77062     205837          14397135        2303             278806
# 77063     173388          14570523        1107             279913
# 77064     185473          14755996        1529             281442
# 77065     216360          14972356        2552             283994
#
# [343 rows x 8 columns]

# %%
plt.style.use('ggplot')
USA.plot(x='Date_reported', y=['New_cases','New_deaths'], title="USA New Cases and New Deaths from 1/3/2020 till 12/8/2020", subplots=True, legend=True, layout=(2,2), figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000012924F84A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012925168F10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001292355D160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012924FEE5E0>]],
#       dtype=object)

# %%
China=dataframe[dataframe.Country == 'China']
China
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 14387    2020-01-03           CN   China       WPRO          0
# 14388    2020-01-04           CN   China       WPRO          1
# 14389    2020-01-05           CN   China       WPRO          0
# 14390    2020-01-06           CN   China       WPRO          3
# 14391    2020-01-07           CN   China       WPRO          0
# ...             ...          ...     ...        ...        ...
# 14725    2020-12-06           CN   China       WPRO        122
# 14726    2020-12-07           CN   China       WPRO        133
# 14727    2020-12-08           CN   China       WPRO         90
# 14728    2020-12-09           CN   China       WPRO        117
# 14729    2020-12-10           CN   China       WPRO        118
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 14387                 0           0                  0
# 14388                 1           0                  0
# 14389                 1           0                  0
# 14390                 4           0                  0
# 14391                 4           0                  0
# ...                 ...         ...                ...
# 14725             94160           0               4753
# 14726             94293           0               4753
# 14727             94383           0               4753
# 14728             94500           0               4753
# 14729             94618           2               4755
#
# [343 rows x 8 columns]

# %%
plt.style.use('ggplot')
China.plot(x='Date_reported', y=['New_cases','New_deaths'], title="China New Cases and New Deaths from 1/3/2020 till 12/8/2020", subplots=True, legend=True, layout=(2,2), figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000012922C1F9D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000129250A1D30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001292516C130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001292520A460>]],
#       dtype=object)

# %%
#load the data
usa_data= pd.read_csv('USA1.csv')
#This will set my index as date column
usa_data.index= pd.to_datetime(usa_data['Date_reported'])
usa_data = usa_data.drop(['Date_reported'], axis=1)
usa_data.head()
# Out:
#                                 Country  Temperature  New_cases  \
# Date_reported
# 2020-01-03     United States of America         49.7          0
# 2020-01-04     United States of America         52.4          0
# 2020-01-05     United States of America         40.8          0
# 2020-01-06     United States of America         44.1          0
# 2020-01-07     United States of America         37.6          0
#
#                Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# 2020-01-03                    0           0                  0
# 2020-01-04                    0           0                  0
# 2020-01-05                    0           0                  0
# 2020-01-06                    0           0                  0
# 2020-01-07                    0           0                  0

# %%
#Check for missing data
usa_data.isna().any()
# Out:
# Country              False
# Temperature          False
# New_cases            False
# Cumulative_cases     False
# New_deaths           False
# Cumulative_deaths    False
# dtype: bool

# %%
#define x & y data
x=usa_data['New_cases']
y=usa_data['Temperature']
plt.plot(x, y,'o', color='cadetblue', label = 'No of New Cases')
#make sure it is formatted
plt.title("USA")
plt.xlabel("New_cases")
plt.ylabel("Temperature")
plt.legend()
plt.show()

# %%
#measuring the coorelation
usa_data.corr()
# Out:
#                    Temperature  New_cases  Cumulative_cases  New_deaths  \
# Temperature           1.000000   0.085548          0.152947    0.172643
# New_cases             0.085548   1.000000          0.884763    0.453587
# Cumulative_cases      0.152947   0.884763          1.000000    0.309909
# New_deaths            0.172643   0.453587          0.309909    1.000000
# Cumulative_deaths     0.406353   0.795409          0.948308    0.337722
#
#                    Cumulative_deaths
# Temperature                 0.406353
# New_cases                   0.795409
# Cumulative_cases            0.948308
# New_deaths                  0.337722
# Cumulative_deaths           1.000000

# %%
#Check the data type of each column
usa_data.dtypes
# Out:
# Country               object
# Temperature          float64
# New_cases              int64
# Cumulative_cases       int64
# New_deaths             int64
# Cumulative_deaths      int64
# dtype: object

# %%
#define x & y data
x=usa_data['New_cases']
y=usa_data['Cumulative_cases']
plt.plot(x, y,'o', color='cadetblue', label = 'Coorelation between No of new cases and current cases')
#make sure it is formatted
plt.title("Coorelation between No of new cases and current cases")
plt.xlabel("New_cases")
plt.ylabel("Cumulative_cases")
plt.legend()
plt.show()

# %%
usa_data.hist(grid= True, color= 'cadetblue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000129254E9BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012925514F10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001292554C3A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000129255777F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000129255A5C40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000129255DE130>]],
#       dtype=object)

# %%
#load the data
china_data= pd.read_csv('China1.csv')
#This will set my index as date column
china_data.index= pd.to_datetime(china_data['Date_reported'])
china_data = china_data.drop(['Date_reported'], axis=1)
china_data.head()
# Out:
#               Country  Temperature  New_cases  Cumulative_cases  New_deaths  \
# Date_reported
# 2020-01-03      China         27.9          0                 0           0
# 2020-01-04      China         33.4          1                 1           0
# 2020-01-05      China         28.8          0                 1           0
# 2020-01-06      China         32.2          3                 4           0
# 2020-01-07      China         32.7          0                 4           0
#
#                Cumulative_deaths
# Date_reported
# 2020-01-03                     0
# 2020-01-04                     0
# 2020-01-05                     0
# 2020-01-06                     0
# 2020-01-07                     0

# %%
#define x & y data
x=china_data['New_cases']
y=china_data['Temperature']
plt.plot(x, y,'o', color='cadetblue', label = 'No of New Cases')
#make sure it is formatted
plt.title("China")
plt.xlabel("New_cases")
plt.ylabel("Temperature")
plt.legend()
plt.show()

# %%
#measuring the coorelation
china_data.corr()
# Out:
#                    Temperature  New_cases  Cumulative_cases  New_deaths  \
# Temperature           1.000000  -0.307022          0.568584   -0.147818
# New_cases            -0.307022   1.000000         -0.287582    0.292804
# Cumulative_cases      0.568584  -0.287582          1.000000   -0.080627
# New_deaths           -0.147818   0.292804         -0.080627    1.000000
# Cumulative_deaths     0.691119  -0.404967          0.934986   -0.152236
#
#                    Cumulative_deaths
# Temperature                 0.691119
# New_cases                  -0.404967
# Cumulative_cases            0.934986
# New_deaths                 -0.152236
# Cumulative_deaths           1.000000

# %%
#define x & y data
x=china_data['New_cases']
y=china_data['Cumulative_cases']
plt.plot(x, y,'o', color='cadetblue', label = 'Coorelation between No of new cases and current cases')
#make sure it is formatted
plt.title("Coorelation between No of new cases and current cases")
plt.xlabel("New_cases")
plt.ylabel("Cumulative_cases")
plt.legend()
plt.show()

# %%
#define x & y data
x=china_data['Cumulative_deaths']
y=china_data['Cumulative_cases']
plt.plot(x, y,'o', color='cadetblue', label = 'Coorelation between current cases and No of Death')
#make sure it is formatted
plt.title("Coorelation between current cases and total number of deaths")
plt.xlabel("Cumulative Deaths")
plt.ylabel("Cumulative_cases")
plt.legend()
plt.show()

# %%
uk_df = dataframe[dataframe.Country == 'The United Kingdom']
uk_df.to_csv('uk.csv')
uk_df.head
# Out:
# <bound method NDFrame.head of       Date_reported Country_code             Country WHO_region  New_cases  \
# 71585    2020-01-03           GB  The United Kingdom       EURO          0
# 71586    2020-01-04           GB  The United Kingdom       EURO          0
# 71587    2020-01-05           GB  The United Kingdom       EURO          0
# 71588    2020-01-06           GB  The United Kingdom       EURO          0
# 71589    2020-01-07           GB  The United Kingdom       EURO          0
# ...             ...          ...                 ...        ...        ...
# 71922    2020-12-05           GB  The United Kingdom       EURO      16298
# 71923    2020-12-06           GB  The United Kingdom       EURO      15539
# 71924    2020-12-07           GB  The United Kingdom       EURO      17271
# 71925    2020-12-08           GB  The United Kingdom       EURO      14718
# 71926    2020-12-09           GB  The United Kingdom       EURO      12281
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 71585                 0           0                  0
# 71586                 0           0                  0
# 71587                 0           0                  0
# 71588                 0           0                  0
# 71589                 0           0                  0
# ...                 ...         ...                ...
# 71922           1690436         504              60617
# 71923           1705975         397              61014
# 71924           1723246         231              61245
# 71925           1737964         189              61434
# 71926           1750245         599              62033
#
# [342 rows x 8 columns]>

# %%
#load the data
uk_data= pd.read_csv('uk.csv')
#This will set my index as date column
uk_data.index= pd.to_datetime(uk_data['Date_reported'])
uk_data = uk_data.drop(['Date_reported'], axis=1)
uk_data.head()
# Out:
#                           Country  New_cases  Cumulative_cases  New_deaths  \
# Date_reported
# 2020-01-03     The United Kingdom          0                 0           0
# 2020-01-04     The United Kingdom          0                 0           0
# 2020-01-05     The United Kingdom          0                 0           0
# 2020-01-06     The United Kingdom          0                 0           0
# 2020-01-07     The United Kingdom          0                 0           0
#
#                Cumulative_deaths
# Date_reported
# 2020-01-03                     0
# 2020-01-04                     0
# 2020-01-05                     0
# 2020-01-06                     0
# 2020-01-07                     0

# %%
uk_data.corr()
# Out:
#                    New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# New_cases           1.000000          0.825346    0.346166           0.529170
# Cumulative_cases    0.825346          1.000000    0.242116           0.752332
# New_deaths          0.346166          0.242116    1.000000           0.082845
# Cumulative_deaths   0.529170          0.752332    0.082845           1.000000

# %%
#define x & y data
x=uk_data['New_cases']
y=uk_data['Cumulative_cases']
plt.plot(x, y,'o', color='cadetblue', label = 'Coorelation between No of new cases and current cases')
#make sure it is formatted
plt.title("Coorelation between No of new cases and current cases")
plt.xlabel("New_cases")
plt.ylabel("Cumulative_cases")
plt.legend()
plt.show()
